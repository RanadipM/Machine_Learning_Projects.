# %% [markdown]
# # 2 - Feature Engineering
#
# In this module, we will try to create new Features which will be helpful to cluster/group the customers more efficiently.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94a88ff9-9cb1-45b0-906e-c5ee15c6703a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94a88ff9-9cb1-45b0-906e-c5ee15c6703a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('marketing_data_clean.csv')
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df['BALANCE_USAGE_RATIO'] = df['BALANCE'] / df['CREDIT_LIMIT']
df['ONEOFF_PURCHASE_RATIO'] = df['ONEOFF_PURCHASES'] / (df['PURCHASES'] + 1e-6)
df['INSTALLMENT_PURCHASE_RATIO'] = df['INSTALLMENTS_PURCHASES'] / (df['PURCHASES'] + 1e-6)
df['TOTAL_PURCHASES'] = df['ONEOFF_PURCHASES'] + df['INSTALLMENTS_PURCHASES']
df['PURCHASES_PER_TRX'] = df['PURCHASES'] / df['PURCHASES_TRX']
df['CASH_ADVANCE_PER_TRX'] = df['CASH_ADVANCE'] / df['CASH_ADVANCE_TRX']
df['PAYMENT_RATIO'] = df['PAYMENTS'] / df['CREDIT_LIMIT']
df['MINIMUM_PAYMENT_RATIO'] = df['MINIMUM_PAYMENTS'] / df['CREDIT_LIMIT']
df['FULL_PAYMENT_FLAG'] = (df['PRC_FULL_PAYMENT'] == 1).astype(int)
df['UTILIZATION_RATIO'] = (df['PURCHASES'] + df['CASH_ADVANCE']) / df['CREDIT_LIMIT']

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Checking missing variable
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# CASH_ADVANCE_PER_TRX      4628
# PURCHASES_PER_TRX         2044
# BALANCE                      0
# ONEOFF_PURCHASES             0
# INSTALLMENTS_PURCHASES       0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
import os
from google.colab import files

# Saving cleaned data
os.makedirs('data', exist_ok=True)

df.to_csv("data/marketing_data_clean_w_features.csv", index=False)

print("Cleaned data is saved to 'data/marketing_data_clean_w_features.csv'")

# Download file (for Google Colab)
files.download("data/marketing_data_clean_w_features.csv")
# Out:
# Cleaned data is saved to 'data/marketing_data_clean_w_features.csv'
